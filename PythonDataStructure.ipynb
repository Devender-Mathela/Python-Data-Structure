# %% [markdown]
# Q1. What are data structures, and why are they important?
# Ans: Data structures are organized ways to store and manage data (e.g., lists, tuples, dictionaries, sets). They are important because they allow efficient data storage, retrieval, and manipulation, which improves performance and solves problems effectively.
#
#
# Q2. Explain the difference between mutable and immutable data types with examples.
# Ans:
#
# Mutable: Mutable data types Can be changed after creation. Example: list = [1, 2, 3] -> list[0] = 10 is allowed.
#
# Immutable:Immutable data types Cannot be changed after creation. Example: tuple = (1, 2, 3)->tuple[0] = 10(error).
#
#
# Q3. What are the main differences between lists and tuples in Python?
# Ans:
#
# List:Lists are Mutable, slower and it is declared by using square brackets []. Ex: [1,2,3,4]
#
# Tuple:Tuples are Immutable, faster and it is declared by using parentheses (). Ex: (1,2,3,4)
#
#
# Q4. Describe how dictionaries store data.
# Ans:
#
# Dictionaries store data in key-value pairs using a hash table. Example: {"name": "Alex", "age": 25} here, "name" is the key, "Alex" is the value.
#
#
# Q5. Why might you use a set instead of a list in Python?
# Ans:
#
# Sets stores the unique value and it  automatically remove duplicate values and allow fast membership checks, making them useful for uniqueness and faster lookups.
#
#
# Q6. What is a string in Python, and how is it different from a list?
# Ans:
#
# String:Strings are the Immutable sequence of characters ("hello").
#
# List:Lists are the Mutable sequence of elements (['h', 'e', 'l', 'l', 'o']).
#
# Strings cannot be modified directly, while lists can i.e string is immutable whereas list is mutable data type.
#
#
# Q7. How do tuples ensure data integrity in Python?
# Ans:
#
# Tuples are immutable, meaning once created, their values cannot be changed. This prevents accidental modification and ensures data safety.
#
#
# Q8. What is a hash table, and how does it relate to dictionaries in Python?
# Ans:
#
# A hash table stores data in key-value pairs using a hash function for quick access. Python dictionaries are implemented using hash tables.
#
#
#
# Q10. Explain why strings are immutable in Python.
# Ans:
#
# Strings are immutable because changing them would require creating a new string object in memory. This ensures efficiency, security, and consistency.
#
#
#
# Q11. What advantages do dictionaries offer over lists for certain tasks?
# Ans:
#
# Dictionaries provide:
#
# -Faster lookups using keys (O(1) average time).
#
# -Better readability by naming elements (data["age"]) instead of using indexes.
#
# -It store the values using hash table hence fasster accessible
#
#
#
# Q12. Describe a scenario where using a tuple would be preferable over a list.
# Ans:
#
# When storing fixed data that should not change, e.g., coordinates (x, y) or days of the week. where we don't want to alter the value after creaing it.
#
#
# Q13. How do sets handle duplicate values in Python?
# Ans:
#
# Sets automatically remove duplicates value. Example: {1, 2, 2, 3} → {1, 2, 3}.
#
#
# Q15. Can you modify the elements of a tuple? Explain why or why not.
# Ans:
#
# No, tuples are immutable data type. Once created, their elements cannot be changed, added, or removed.
#
#
# Q16. What is a nested dictionary, and give an example of its use case.
# Ans:
#
# A nested dictionary is a dictionary inside another dictionary.
# Example:
#
# student = {
#   "name": "Alice",
#   "marks": {"math": 90, "science": 85}
# }
#
#
#
# Q17. Describe the time complexity of accessing elements in a dictionary.
# Ans:
#
# Dictionary access is O(1) average time due to hashing, but can degrade to O(n) in rare cases of hash collisions.
#
#
#
# Q18. In what situations are lists preferred over dictionaries?
# Ans:
#
# -When order matters.
#
# -When you only need a sequence of values without unique keys.
#
# -For operations requiring indexing.
#
#
# Q19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# Ans:
#
# Dictionaries (before Python 3.7) didn't guarantee order because they use hashing. In modern Python (3.7+), they preserve insertion order, but retrieval is still by key, not by position.
#
#
#
# Q20. Explain the difference between a list and a dictionary in terms of data retrieval.
# Ans:
#
# List: Retrieve by index -> list[2].
#
# Dictionary: Retrieve by key -> dict["name"].
#
# Dictionaries are faster for lookups when using meaningful keys.

# %%
#Practical Question
#Q1. Write a code to create a string with your name and print it.

name = "Deepu"
print(name)

#Output: Deepu



#Q2. Write a code to find the length of the string "Hello World".

text = "Hello World"
print(len(text))

#output:11



#Q3. Write a code to slice the first 3 characters from the string "Python Programming".

text = "Python Programming"
print(text[:3])

#output:Pyt


#Q4. Write a code to convert the string "hello" to uppercase.

text = "hello"
print(text.upper())

#output:HELLO


#Q5. Write a code to replace the word "apple" with "orange" in the string "I like apple".


text = "I like apple"
print(text.replace("apple", "orange"))


#output:I like orange



#Q6. Write a code to create a list with numbers 1 to 5 and print it.

numbers = [1, 2, 3, 4, 5]
print(numbers)

#output:[1,2,3,4,5]



# Q8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print(numbers)

# output:[1,2,4,5]


# Q9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

letters = ['a', 'b', 'c', 'd']
print(letters[1])


# output:b


# Q10. Write a code to reverse the list [10, 20, 30, 40, 50].

numbers = [10, 20, 30, 40, 50]
numbers.reverse()
print(numbers)


# output:[50,40,30,20,10]



# Q11. Write a code to create a tuple with the elements 100, 200, 300 and print it.


numbers = (100, 200, 300)
print(numbers)


# output:(100,200,300)


# Q12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').


colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])


# output:blue


# Q13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).


numbers = (10, 20, 5, 15)
print(min(numbers))

# output:5


# Q14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').


animals = ('dog', 'cat', 'rabbit')
print(animals.index("cat"))

# output:1


# Q15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

fruits = ("apple", "banana", "mango")
print("kiwi" in fruits)

# output:False


# Q16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

letters = {'a', 'b', 'c'}
print(letters)

# output:{'a', 'b', 'c'}


# Q17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

numbers = {1, 2, 3, 4, 5}
numbers.clear()
print(numbers)

output:set()



# Q18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

numbers = {1, 2, 3, 4}
numbers.remove(4)
print(numbers)

# output:{1, 2, 3}



# Q19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
print(set1.union(set2))

# output:{1, 2, 3, 4, 5}



# Q20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

set1 = {1, 2, 3}
set2 = {2, 3, 4}
print(set1.intersection(set2))

# output:{2.3}


# Q21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.


person = {"name": "JohnCena", "age": 25, "city": "New York"}
print(person)

# output:{'name': 'JohnCena', 'age': 25, 'city': 'New York'}



# Q22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

person = {'name': 'John', 'age': 25}
person["country"] = "USA"
print(person)

# output:{'name': 'John', 'age': 25, 'country': 'USA'}



# Q23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

person = {'name': 'Alice', 'age': 30}
print(person["name"])

# output:Alice


# Q24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
person.pop("age")
print(person)

# output:{'name': 'Bob', 'city': 'New York'}


# Q25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

person = {'name': 'Alice', 'city': 'Paris'}
print("city" in person)

# output:True


# Q26. Write a code to create a list, a tuple, and a dictionary, and print them all.

my_list = [1, 2, 3]
my_tuple = (4, 5, 6)
my_dict = {"a": 1, "b": 2}
print(my_list, my_tuple, my_dict)

# output:[1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}


# Q27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.

import random
numbers = random.sample(range(1, 101), 5)
numbers.sort()
print(numbers)

# output:[3, 17, 42, 65, 90]


# Q28. Write a code to create a list with strings and print the element at the third index.

words = ["apple", "banana", "cherry", "date", "fig"]
print(words[3])

# output:date


# Q29. Write a code to combine two dictionaries into one and print the result.

dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}
dict1.update(dict2)
print(dict1)


# output:{'a': 1, 'b': 2, 'c': 3, 'd': 4}



# Q30. Write a code to convert a list of strings into a set.

words = ["apple", "banana", "apple", "cherry"]
unique = set(words)
print(unique)

# output:{'banana', 'cherry', 'apple'}
# Out:
# Deepu
# 11
# Pyt
# HELLO
# I like orange
# [1, 2, 3, 4, 5]
# [1, 2, 4, 5]
# b
# [50, 40, 30, 20, 10]
# (100, 200, 300)
# blue
# 5
# 1
# False
# {'a', 'b', 'c'}
# set()
# {1, 2, 3}
